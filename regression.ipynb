# %%
import pandas as pd
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import numpy as np

# %%
# load data
df = pd.read_parquet(
    r"https://github.com/ISL-0111/IDS701_Team_Project/raw/refs/heads/main/Data/cleaned_data.parquet"
)
df.sample(5)
# Out:
#         order_id  region_id      city  courier_id        lng       lat  \
# 942814   3757269         61  Shanghai        3053  121.36807  31.34657
# 163104   1890415          8  Shanghai         191  121.52519  31.14764
# 267631   1553144         16  Shanghai        3699  121.34429  31.40269
# 232223   1659176          9  Shanghai        4721  121.46369  30.90742
# 815876   2597734         50  Shanghai        1991  121.47044  31.22071
#
#         aoi_id  aoi_type         accept_time     accept_gps_time  ...  \
# 942814   23436         1 2023-10-31 08:59:00 2023-10-31 08:59:00  ...
# 163104    9058         1 2023-09-30 11:11:00 2023-09-30 11:11:00  ...
# 267631   30108        14 2023-10-27 09:55:00 2023-10-27 09:55:00  ...
# 232223   44573         1 2023-07-12 20:46:00 2023-07-12 20:46:00  ...
# 815876   13220         1 2023-10-05 08:40:00 2023-10-05 08:40:00  ...
#
#              delivery_time   delivery_gps_time delivery_gps_lng  \
# 942814 2023-10-31 10:12:00 2023-10-31 10:12:00        121.36844
# 163104 2023-09-30 13:03:00 2023-09-30 13:03:00        121.52558
# 267631 2023-10-27 13:11:00 2023-10-27 13:11:00        121.34383
# 232223 2023-07-12 21:48:00 2023-07-12 21:48:00        121.46360
# 815876 2023-10-05 09:15:00 2023-10-05 09:15:00        121.47064
#
#        delivery_gps_lat    ds  distance_km  accept_date  delivery_duration  \
# 942814         31.34638  1031     1.906986   2023-10-31    0 days 01:13:00
# 163104         31.14817   930     3.218530   2023-09-30    0 days 01:52:00
# 267631         31.40220  1027     1.253373   2023-10-27    0 days 03:16:00
# 232223         30.90759   712     2.234353   2023-07-12    0 days 01:02:00
# 815876         31.22023  1005     3.180122   2023-10-05    0 days 00:35:00
#
#        delivery_duration_minutes delivery_under_30
# 942814                      73.0             False
# 163104                     112.0             False
# 267631                     196.0             False
# 232223                      62.0             False
# 815876                      35.0             False
#
# [5 rows x 22 columns]

# %%
print(df.shape)
# Out:
# (1469084, 23)

# %%
print(df.describe)
# Out:
# <bound method NDFrame.describe of          order_id  region_id      city  courier_id        lng       lat  \
# 0         3158819          1  Shanghai         164  121.52128  31.06614
# 1          751342          1  Shanghai         164  121.52124  31.06687
# 2         3380476          1  Shanghai         164  121.52106  31.06731
# 3         2184571          1  Shanghai         164  121.52128  31.06616
# 4          941371          1  Shanghai         164  121.52123  31.06614
# ...           ...        ...       ...         ...        ...       ...
# 1469079   3803282         93  Shanghai        2690  121.55562  31.07862
# 1469080    960937         93  Shanghai        2690  121.55559  31.07807
# 1469081   3894541         93  Shanghai        2690  121.55567  31.07864
# 1469082   3946912         93  Shanghai        2690  121.55574  31.07873
# 1469083   1320044         93  Shanghai        2690  121.55565  31.07866
#
#          aoi_id  aoi_type         accept_time     accept_gps_time  ...  \
# 0           450         1 2023-06-04 11:05:00 2023-06-04 11:05:00  ...
# 1           450         1 2023-06-04 11:18:00 2023-06-04 11:18:00  ...
# 2           450         1 2023-06-03 10:13:00 2023-06-03 10:13:00  ...
# 3           450         1 2023-06-04 10:39:00 2023-06-04 10:39:00  ...
# 4           450         1 2023-06-04 11:18:00 2023-06-04 11:18:00  ...
# ...         ...       ...                 ...                 ...  ...
# 1469079   60110        14 2023-10-26 12:10:00 2023-10-26 12:10:00  ...
# 1469080   60110        14 2023-10-22 13:28:00 2023-10-22 13:28:00  ...
# 1469081   60110        14 2023-10-21 13:53:00 2023-10-21 13:53:00  ...
# 1469082   60110        14 2023-10-20 08:56:00 2023-10-20 08:56:00  ...
# 1469083   60110        14 2023-10-18 15:07:00 2023-10-18 15:07:00  ...
#
#           delivery_gps_time  delivery_gps_lng delivery_gps_lat    ds  \
# 0       2023-06-04 17:40:00         121.52407         31.06614   604
# 1       2023-06-04 15:06:00         121.52412         31.06618   604
# 2       2023-06-03 15:11:00         121.52059         31.06672   603
# 3       2023-06-04 15:41:00         121.52280         31.10542   604
# 4       2023-06-04 14:07:00         121.52290         31.06758   604
# ...                     ...               ...              ...   ...
# 1469079 2023-10-26 13:29:00         121.55540         31.07859  1026
# 1469080 2023-10-22 16:37:00         121.56303         31.07953  1022
# 1469081 2023-10-21 14:21:00         121.55509         31.07841  1021
# 1469082 2023-10-20 09:12:00         121.55703         31.07842  1020
# 1469083 2023-10-18 16:54:00         121.55643         31.08042  1018
#
#          distance_km  accept_date  delivery_duration  \
# 0           4.418734   2023-06-04    0 days 06:35:00
# 1           4.415409   2023-06-04    0 days 03:48:00
# 2           4.350380   2023-06-03    0 days 04:58:00
# 3           0.056577   2023-06-04    0 days 05:02:00
# 4           4.251904   2023-06-04    0 days 02:49:00
# ...              ...          ...                ...
# 1469079     3.338471   2023-10-26    0 days 01:19:00
# 1469080     3.997358   2023-10-22    0 days 03:09:00
# 1469081     3.309780   2023-10-21    0 days 00:28:00
# 1469082     3.456926   2023-10-20    0 days 00:16:00
# 1469083     3.552454   2023-10-18    0 days 01:47:00
#
#          delivery_duration_minutes delivery_under_30 accept_hour
# 0                            395.0             False          11
# 1                            228.0             False          11
# 2                            298.0             False          10
# 3                            302.0             False          10
# 4                            169.0             False          11
# ...                            ...               ...         ...
# 1469079                       79.0             False          12
# 1469080                      189.0             False          13
# 1469081                       28.0              True          13
# 1469082                       16.0              True           8
# 1469083                      107.0             False          15
#
# [1469084 rows x 23 columns]>

# %%
print(df.info)
# Out:
# <bound method DataFrame.info of          order_id  region_id      city  courier_id        lng       lat  \
# 0         3158819          1  Shanghai         164  121.52128  31.06614
# 1          751342          1  Shanghai         164  121.52124  31.06687
# 2         3380476          1  Shanghai         164  121.52106  31.06731
# 3         2184571          1  Shanghai         164  121.52128  31.06616
# 4          941371          1  Shanghai         164  121.52123  31.06614
# ...           ...        ...       ...         ...        ...       ...
# 1469079   3803282         93  Shanghai        2690  121.55562  31.07862
# 1469080    960937         93  Shanghai        2690  121.55559  31.07807
# 1469081   3894541         93  Shanghai        2690  121.55567  31.07864
# 1469082   3946912         93  Shanghai        2690  121.55574  31.07873
# 1469083   1320044         93  Shanghai        2690  121.55565  31.07866
#
#          aoi_id  aoi_type         accept_time     accept_gps_time  ...  \
# 0           450         1 2023-06-04 11:05:00 2023-06-04 11:05:00  ...
# 1           450         1 2023-06-04 11:18:00 2023-06-04 11:18:00  ...
# 2           450         1 2023-06-03 10:13:00 2023-06-03 10:13:00  ...
# 3           450         1 2023-06-04 10:39:00 2023-06-04 10:39:00  ...
# 4           450         1 2023-06-04 11:18:00 2023-06-04 11:18:00  ...
# ...         ...       ...                 ...                 ...  ...
# 1469079   60110        14 2023-10-26 12:10:00 2023-10-26 12:10:00  ...
# 1469080   60110        14 2023-10-22 13:28:00 2023-10-22 13:28:00  ...
# 1469081   60110        14 2023-10-21 13:53:00 2023-10-21 13:53:00  ...
# 1469082   60110        14 2023-10-20 08:56:00 2023-10-20 08:56:00  ...
# 1469083   60110        14 2023-10-18 15:07:00 2023-10-18 15:07:00  ...
#
#           delivery_gps_time  delivery_gps_lng delivery_gps_lat    ds  \
# 0       2023-06-04 17:40:00         121.52407         31.06614   604
# 1       2023-06-04 15:06:00         121.52412         31.06618   604
# 2       2023-06-03 15:11:00         121.52059         31.06672   603
# 3       2023-06-04 15:41:00         121.52280         31.10542   604
# 4       2023-06-04 14:07:00         121.52290         31.06758   604
# ...                     ...               ...              ...   ...
# 1469079 2023-10-26 13:29:00         121.55540         31.07859  1026
# 1469080 2023-10-22 16:37:00         121.56303         31.07953  1022
# 1469081 2023-10-21 14:21:00         121.55509         31.07841  1021
# 1469082 2023-10-20 09:12:00         121.55703         31.07842  1020
# 1469083 2023-10-18 16:54:00         121.55643         31.08042  1018
#
#          distance_km  accept_date  delivery_duration  \
# 0           4.418734   2023-06-04    0 days 06:35:00
# 1           4.415409   2023-06-04    0 days 03:48:00
# 2           4.350380   2023-06-03    0 days 04:58:00
# 3           0.056577   2023-06-04    0 days 05:02:00
# 4           4.251904   2023-06-04    0 days 02:49:00
# ...              ...          ...                ...
# 1469079     3.338471   2023-10-26    0 days 01:19:00
# 1469080     3.997358   2023-10-22    0 days 03:09:00
# 1469081     3.309780   2023-10-21    0 days 00:28:00
# 1469082     3.456926   2023-10-20    0 days 00:16:00
# 1469083     3.552454   2023-10-18    0 days 01:47:00
#
#          delivery_duration_minutes delivery_under_30 accept_hour
# 0                            395.0             False          11
# 1                            228.0             False          11
# 2                            298.0             False          10
# 3                            302.0             False          10
# 4                            169.0             False          11
# ...                            ...               ...         ...
# 1469079                       79.0             False          12
# 1469080                      189.0             False          13
# 1469081                       28.0              True          13
# 1469082                       16.0              True           8
# 1469083                      107.0             False          15
#
# [1469084 rows x 23 columns]>

# %%
# prepare dataset
df["accept_hour"] = df["accept_time"].dt.hour

# %%
# Filter Data for Top Regions
n_regions_under_consideration = 14
top_regions = df["region_id"].value_counts().head(n_regions_under_consideration).index
df_filtered = df[df["region_id"].isin(top_regions)]

# Keep only necessary columns
df_filtered = df_filtered[
    [
        "order_id",
        "region_id",
        "courier_id",
        "delivery_duration_minutes",
        "accept_date",
        "distance_km",
        "accept_hour",
    ]
]

print(df.shape)
df.sample(5)
# Out:
# (1469084, 23)
#          order_id  region_id      city  courier_id        lng       lat  \
# 1010192    209054         65  Shanghai        4252  121.42614  31.16266
# 787903    1447175         46  Shanghai        4837  121.56722  31.26474
# 1372314   1722806         87  Shanghai        2786  121.45691  31.22481
# 972691    1767243         63  Shanghai        1256  121.37551  31.16603
# 452827    4155040         29  Shanghai        3618  121.41026  31.24522
#
#          aoi_id  aoi_type         accept_time     accept_gps_time  ...  \
# 1010192   26831         1 2023-08-09 18:09:00 2023-08-09 18:09:00  ...
# 787903    27519         1 2023-06-19 21:37:00 2023-06-19 21:37:00  ...
# 1372314    4117         0 2023-07-25 16:24:00 2023-07-25 16:24:00  ...
# 972691    29057         1 2023-06-28 09:04:00 2023-06-28 09:04:00  ...
# 452827    26350         0 2023-10-22 15:34:00 2023-10-22 15:34:00  ...
#
#           delivery_gps_time  delivery_gps_lng delivery_gps_lat    ds  \
# 1010192 2023-08-09 18:30:00         121.42618         31.16260   809
# 787903  2023-06-19 22:28:00         121.56734         31.26492   619
# 1372314 2023-07-25 19:20:00         121.45675         31.22431   725
# 972691  2023-06-28 11:26:00         121.37566         31.16610   628
# 452827  2023-10-22 16:28:00         121.41063         31.24541  1022
#
#          distance_km  accept_date  delivery_duration  \
# 1010192     1.857016   2023-08-09    0 days 00:21:00
# 787903      1.169675   2023-06-19    0 days 00:51:00
# 1372314     2.698517   2023-07-25    0 days 02:56:00
# 972691      1.699861   2023-06-28    0 days 02:22:00
# 452827      1.174223   2023-10-22    0 days 00:54:00
#
#          delivery_duration_minutes delivery_under_30 accept_hour
# 1010192                       21.0              True          18
# 787903                        51.0             False          21
# 1372314                      176.0             False          16
# 972691                       142.0             False           9
# 452827                        54.0             False          15
#
# [5 rows x 23 columns]

# %%
# Create Daily Aggregations per Courier
daily_agg = (
    df_filtered.groupby(["courier_id", "accept_date"])
    .agg(
        task_count=("order_id", "nunique"),  # Number of tasks per day
        avg_delivery_duration_min=("delivery_duration_minutes", "mean"),
        avg_distance_km=("distance_km", "mean"),
        delivery_hour_mode=(
            "accept_hour",
            lambda x: x.mode()[0],
        ),  # Most frequent hour that day
    )
    .reset_index()
)

# %%
# --- Step 3: Create 'high_load' Flag ---
# Define high_load as days with task_count > median daily tasks across all couriers
median_daily_tasks = daily_agg["task_count"].median()
daily_agg["high_load"] = (daily_agg["task_count"] > median_daily_tasks).astype(int)

# %%
# --- Step 4: Run Regression ---
model = smf.ols(
    formula="np.log(avg_delivery_duration_min) ~ task_count * high_load + avg_distance_km + C(delivery_hour_mode)",
    data=daily_agg,
).fit(cov_type="HC3")
# Out:
# /Users/yirang/miniforge3/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
# --- Step 4: Run Regression ---
model = smf.ols(
    formula="np.log(avg_delivery_duration_min) ~ task_count * high_load + avg_distance_km + C(delivery_hour_mode)",
    data=daily_agg,
).fit(cov_type="HC3")
# Out:
# /Users/yirang/miniforge3/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/yirang/miniforge3/lib/python3.12/site-packages/statsmodels/regression/linear_model.py:1733: RuntimeWarning: invalid value encountered in subtract
#   return np.sum(weights * (model.endog - mean)**2)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 8
#       2 model = smf.ols(
#       3     formula="np.log(avg_delivery_duration_min) ~ task_count * high_load + avg_distance_km + C(delivery_hour_mode)",
#       4     data=daily_agg,
#       5 ).fit(cov_type="HC3")
#       7 # Step 5: Print Results ---
# ----> 8 print(model.summary())
#
# File ~/miniforge3/lib/python3.12/site-packages/statsmodels/regression/linear_model.py:2779, in RegressionResults.summary(self, yname, xname, title, alpha, slim)
#    2772     top_left.append(('Covariance Type:', [self.cov_type]))
#    2774 rsquared_type = '' if self.k_constant else ' (uncentered)'
#    2775 top_right = [('R-squared' + rsquared_type + ':',
#    2776               ["%#8.3f" % self.rsquared]),
#    2777              ('Adj. R-squared' + rsquared_type + ':',
#    2778               ["%#8.3f" % self.rsquared_adj]),
# -> 2779              ('F-statistic:', ["%#8.4g" % self.fvalue]),
#    2780              ('Prob (F-statistic):', ["%#6.3g" % self.f_pvalue]),
#    2781              ('Log-Likelihood:', None),
#    2782              ('AIC:', ["%#8.4g" % self.aic]),
#    2783              ('BIC:', ["%#8.4g" % self.bic])
#    2784              ]
#    2786 if slim:
#    2787     slimlist = ['Dep. Variable:', 'Model:', 'No. Observations:',
#    2788                 'Covariance Type:', 'R-squared:', 'Adj. R-squared:',
#    2789                 'F-statistic:', 'Prob (F-statistic):']
#
# File properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~/miniforge3/lib/python3.12/site-packages/statsmodels/regression/linear_model.py:1865, in RegressionResults.fvalue(self)
#    1863     if mat.size == 0:  # see  #3642
#    1864         return np.nan
# -> 1865 ft = self.f_test(mat)
#    1866 # using backdoor to set another attribute that we already have
#    1867 self._cache['f_pvalue'] = float(ft.pvalue)
#
# File ~/miniforge3/lib/python3.12/site-packages/statsmodels/base/model.py:1784, in LikelihoodModelResults.f_test(self, r_matrix, cov_p, invcov)
#    1691 def f_test(self, r_matrix, cov_p=None, invcov=None):
#    1692     """
#    1693     Compute the F-test for a joint linear hypothesis.
#    1694
#    (...)
#    1782     <F test: F=array([[ 144.17976065]]), p=6.322026217355609e-08, df_denom=9, df_num=3>
#    1783     """
# -> 1784     res = self.wald_test(r_matrix, cov_p=cov_p, invcov=invcov, use_f=True, scalar=True)
#    1785     return res
#
# File ~/miniforge3/lib/python3.12/site-packages/statsmodels/base/model.py:1888, in LikelihoodModelResults.wald_test(self, r_matrix, cov_p, invcov, use_f, df_constraints, scalar)
#    1886 cov_p = self.cov_params(r_matrix=r_matrix, cov_p=cov_p)
#    1887 if np.isnan(cov_p).max():
# -> 1888     raise ValueError("r_matrix performs f_test for using "
#    1889                      "dimensions that are asymptotically "
#    1890                      "non-normal")
#    1891 invcov = np.linalg.pinv(cov_p)
#    1892 J_ = np.linalg.matrix_rank(cov_p)
#
# ValueError: r_matrix performs f_test for using dimensions that are asymptotically non-normal

# %%
# Step 5: Print Results ---
print(model.summary())
# Out:
# /Users/yirang/miniforge3/lib/python3.12/site-packages/statsmodels/regression/linear_model.py:1733: RuntimeWarning: invalid value encountered in subtract
#   return np.sum(weights * (model.endog - mean)**2)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 2
#       1 # Step 5: Print Results ---
# ----> 2 print(model.summary())
#
# File ~/miniforge3/lib/python3.12/site-packages/statsmodels/regression/linear_model.py:2779, in RegressionResults.summary(self, yname, xname, title, alpha, slim)
#    2772     top_left.append(('Covariance Type:', [self.cov_type]))
#    2774 rsquared_type = '' if self.k_constant else ' (uncentered)'
#    2775 top_right = [('R-squared' + rsquared_type + ':',
#    2776               ["%#8.3f" % self.rsquared]),
#    2777              ('Adj. R-squared' + rsquared_type + ':',
#    2778               ["%#8.3f" % self.rsquared_adj]),
# -> 2779              ('F-statistic:', ["%#8.4g" % self.fvalue]),
#    2780              ('Prob (F-statistic):', ["%#6.3g" % self.f_pvalue]),
#    2781              ('Log-Likelihood:', None),
#    2782              ('AIC:', ["%#8.4g" % self.aic]),
#    2783              ('BIC:', ["%#8.4g" % self.bic])
#    2784              ]
#    2786 if slim:
#    2787     slimlist = ['Dep. Variable:', 'Model:', 'No. Observations:',
#    2788                 'Covariance Type:', 'R-squared:', 'Adj. R-squared:',
#    2789                 'F-statistic:', 'Prob (F-statistic):']
#
# File properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~/miniforge3/lib/python3.12/site-packages/statsmodels/regression/linear_model.py:1865, in RegressionResults.fvalue(self)
#    1863     if mat.size == 0:  # see  #3642
#    1864         return np.nan
# -> 1865 ft = self.f_test(mat)
#    1866 # using backdoor to set another attribute that we already have
#    1867 self._cache['f_pvalue'] = float(ft.pvalue)
#
# File ~/miniforge3/lib/python3.12/site-packages/statsmodels/base/model.py:1784, in LikelihoodModelResults.f_test(self, r_matrix, cov_p, invcov)
#    1691 def f_test(self, r_matrix, cov_p=None, invcov=None):
#    1692     """
#    1693     Compute the F-test for a joint linear hypothesis.
#    1694
#    (...)
#    1782     <F test: F=array([[ 144.17976065]]), p=6.322026217355609e-08, df_denom=9, df_num=3>
#    1783     """
# -> 1784     res = self.wald_test(r_matrix, cov_p=cov_p, invcov=invcov, use_f=True, scalar=True)
#    1785     return res
#
# File ~/miniforge3/lib/python3.12/site-packages/statsmodels/base/model.py:1888, in LikelihoodModelResults.wald_test(self, r_matrix, cov_p, invcov, use_f, df_constraints, scalar)
#    1886 cov_p = self.cov_params(r_matrix=r_matrix, cov_p=cov_p)
#    1887 if np.isnan(cov_p).max():
# -> 1888     raise ValueError("r_matrix performs f_test for using "
#    1889                      "dimensions that are asymptotically "
#    1890                      "non-normal")
#    1891 invcov = np.linalg.pinv(cov_p)
#    1892 J_ = np.linalg.matrix_rank(cov_p)
#
# ValueError: r_matrix performs f_test for using dimensions that are asymptotically non-normal

# %%
# --- Diagnostic Checks ---
# Check for multicollinearity
from statsmodels.stats.outliers_influence import variance_inflation_factor

X = daily_agg[["task_count", "high_load", "avg_distance_km"]]  # Exclude categorical
X["interaction"] = X["task_count"] * X["high_load"]  # Add interaction term
X = sm.add_constant(X)
print(
    pd.DataFrame(
        {
            "VIF": [variance_inflation_factor(X.values, i) for i in range(X.shape[1])],
            "feature": X.columns,
        }
    )
)

# %%
# Check residuals
plt.scatter(model.fittedvalues, model.resid)
plt.xlabel("Fitted Values")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()
